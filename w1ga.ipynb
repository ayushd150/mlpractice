# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Week1_GA_dataset.csv')

# %%
df.shape
# Out:
# (10000, 12)

# %%
df.replace('?', np.nan, inplace=True)
total_unknown = df.isna().sum().sum()
print(total_unknown)
# Out:
# 5548

# %%
value = df.iloc[692,0]
print(value)
# Out:
# 2009-11-16

# %%
value1 = df.iloc[546,7]
print(value1)
# Out:
# 3

# %%
unique_locality = df['Locality'].unique()
print(unique_locality)
unique_locality1 = df['Locality'].dropna().unique()
print(unique_locality1)
# Out:
# ['Waterbury' 'Bridgeport' 'Greenwich' 'Norwalk' nan 'Fairfield'
#  'West Hartford' 'Stamford']
# ['Waterbury' 'Bridgeport' 'Greenwich' 'Norwalk' 'Fairfield'
#  'West Hartford' 'Stamford']

# %%
missing_columns = df.columns[df.isna().any()].tolist()
print(missing_columns)
# Out:
# ['Locality', 'Estimated Value', 'Property', 'carpet_area']

# %%
missing_count = df.isna().sum()
max_missing_column = missing_count.idxmax()
print(max_missing_column)
# Out:
# Property

# %%
df_clean = df[df.isna().sum(axis=1)<=2]
print(len(df_clean))
# Out:
# 9917

# %%
df_cleaned = df.dropna()
print(len(df_cleaned))
# Out:
# 5449

# %%
even_rows = df.iloc[::2]
value = even_rows.iloc[0,3]
print(value)
# Out:
# 111440.0

# %%
even_rows = df.iloc[::2]
value = even_rows.iloc[332,3]
print(value)
# Out:
# 256200.0

# %%
odd_rows = df.iloc[1::2]
value2 = odd_rows.iloc[332,3]
print(value2)
# Out:
# 352940.0

# %%
odd_rows = df.iloc[:, 1::2]
value3 = odd_rows.iloc[100,5]
print(value3)
# Out:
# West

# %%
even = df.iloc[::2, ::2]
val = even.iloc[255, 3]
print(val)
# Out:
# Duplex

# %%
even_df = df.iloc[::2, ::2]
check =  even_df.iloc[255, 3]
print(check)
# Out:
# Detached House

# %%
recent_yrs = sorted(df['Year'].unique())[-6:]
recent_df = df[df['Year'].isin(recent_yrs)]
count=recent_df.shape[0]
print(count)
print(recent_yrs)
# Out:
# 4749
# [np.int64(2017), np.int64(2018), np.int64(2019), np.int64(2020), np.int64(2021), np.int64(2022)]

# %%
count_and = df[(df['num_rooms'] == 3) & (df['num_bathrooms'] == 3)].shape[0]
print(count_and)
# Out:
# 2730

# %%
count_or = df[(df['num_rooms'] == 3) | (df['num_bathrooms'] == 3)].shape[0]
print(count_or)
# Out:
# 8591

# %%
cond1 = (
    (df['Year'] == 2022) &
    (df['Locality'] == 'Greenwich') &
    (df['num_rooms'] == 3) &
    (df['Face'].isin(['North', 'East']))
)
count_greenwich = df[cond1].shape[0]
print(count_greenwich)
# Out:
# 42

# %%
df[pd.to_datetime(df['Date']).dt.month == 8].shape
# Out:
# (1050, 12)

# %%
avg_price = df.groupby('Locality')['Sale Price'].mean()
highest = avg_price.idxmax()
print(highest)
# Out:
# Greenwich
